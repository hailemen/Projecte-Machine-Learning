# %% [markdown]
# **Ejercicio 1:** Selecciona una API pública y extrae datos utilizando Python.
#
# Tengo como afición la astronomía y me ha parecido interesante realizar este ejercicio con algo relacionado al tema.
#
# Selecciono la API de la NASA, del Servicio de Detección de objetos Cercanos a la Tierra (NeoWs) que se encuentra dentro de la página https://api.nasa.gov/ para ver si puedo obtener algunos datos relacionados con objetos entre los días 17 y 18 de octubre de 2024.

# %%
import requests
import pandas as pd

# Hago la solicitud a  la API de la NASA 

URL = "https://api.nasa.gov/neo/rest/v1/feed?start_date=2024-10-17&end_date=2024-10-18&api_key=DEMO_KEY"
response = requests.get(URL)

if response.status_code == 200:
    data = response.json()
    print("Solicitud Exitosa")
    
else:
    print("Error en la solicitud, detalles:", response.text)
# Out:
# Solicitud Exitosa

# %% [markdown]
# Quiero saber como están estructurados los datos del objeto creado y los inspecciono mediante la función "keys"

# %%
data.keys()
# Out:
# dict_keys(['links', 'element_count', 'near_earth_objects'])

# %% [markdown]
# Dentro del campo near_earth_objects creo que es donde puedo encontrar los datos importantes, consulto la estructura para poder elegir los datos que me interesan para crear un dataframe con ellos

# %%
data['near_earth_objects']
# Out:
# {'2024-10-18': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2483547?api_key=DEMO_KEY'},
#    'id': '2483547',
#    'neo_reference_id': '2483547',
#    'name': '483547 (2003 WM25)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2483547',
#    'absolute_magnitude_h': 17.65,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.7844314124,
#      'estimated_diameter_max': 1.7540419619},
#     'meters': {'estimated_diameter_min': 784.4314124479,
#      'estimated_diameter_max': 1754.0419619197},
#     'miles': {'estimated_diameter_min': 0.4874229312,
#      'estimated_diameter_max': 1.0899108079},
#     'feet': {'estimated_diameter_min': 2573.5939552157,
#      'estimated_diameter_max': 5754.7310303447}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 20:50',
#      'epoch_date_close_approach': 1729284600000,
#      'relative_velocity': {'kilometers_per_second': '9.3986954613',
#       'kilometers_per_hour': '33835.3036607875',
#       'miles_per_hour': '21023.9418774488'},
#      'miss_distance': {'astronomical': '0.2423447257',
#       'lunar': '94.2720982973',
#       'kilometers': '36254254.770454259',
#       'miles': '22527349.3072924142'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3137843?api_key=DEMO_KEY'},
#    'id': '3137843',
#    'neo_reference_id': '3137843',
#    'name': '(2002 RD27)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3137843',
#    'absolute_magnitude_h': 18.14,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.6259720997,
#      'estimated_diameter_max': 1.3997161669},
#     'meters': {'estimated_diameter_min': 625.9720996596,
#      'estimated_diameter_max': 1399.716166857},
#     'miles': {'estimated_diameter_min': 0.3889609095,
#      'estimated_diameter_max': 0.8697430343},
#     'feet': {'estimated_diameter_min': 2053.7143034471,
#      'estimated_diameter_max': 4592.2447888713}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 05:54',
#      'epoch_date_close_approach': 1729230840000,
#      'relative_velocity': {'kilometers_per_second': '12.6975359942',
#       'kilometers_per_hour': '45711.1295791214',
#       'miles_per_hour': '28403.1182654269'},
#      'miss_distance': {'astronomical': '0.4661445277',
#       'lunar': '181.3302212753',
#       'kilometers': '69734228.456075999',
#       'miles': '43330840.2848428262'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3145497?api_key=DEMO_KEY'},
#    'id': '3145497',
#    'neo_reference_id': '3145497',
#    'name': '(2002 YO2)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3145497',
#    'absolute_magnitude_h': 22.7,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0766575574,
#      'estimated_diameter_max': 0.1714115092},
#     'meters': {'estimated_diameter_min': 76.6575573531,
#      'estimated_diameter_max': 171.4115092306},
#     'miles': {'estimated_diameter_min': 0.0476327831,
#      'estimated_diameter_max': 0.1065101409},
#     'feet': {'estimated_diameter_min': 251.5011804664,
#      'estimated_diameter_max': 562.3737359442}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 18:09',
#      'epoch_date_close_approach': 1729274940000,
#      'relative_velocity': {'kilometers_per_second': '4.4510357534',
#       'kilometers_per_hour': '16023.7287122918',
#       'miles_per_hour': '9956.5218768126'},
#      'miss_distance': {'astronomical': '0.4614589274',
#       'lunar': '179.5075227586',
#       'kilometers': '69033272.631524638',
#       'miles': '42895286.5323624844'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3529626?api_key=DEMO_KEY'},
#    'id': '3529626',
#    'neo_reference_id': '3529626',
#    'name': '(2010 MA)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3529626',
#    'absolute_magnitude_h': 25.7,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0192555078,
#      'estimated_diameter_max': 0.0430566244},
#     'meters': {'estimated_diameter_min': 19.2555078188,
#      'estimated_diameter_max': 43.0566244241},
#     'miles': {'estimated_diameter_min': 0.0119648141,
#      'estimated_diameter_max': 0.0267541378},
#     'feet': {'estimated_diameter_min': 63.1742402722,
#      'estimated_diameter_max': 141.2618956756}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 21:59',
#      'epoch_date_close_approach': 1729288740000,
#      'relative_velocity': {'kilometers_per_second': '8.5877838298',
#       'kilometers_per_hour': '30916.0217873705',
#       'miles_per_hour': '19210.0136489359'},
#      'miss_distance': {'astronomical': '0.3083990408',
#       'lunar': '119.9672268712',
#       'kilometers': '46135839.613723096',
#       'miles': '28667481.4071908848'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3761647?api_key=DEMO_KEY'},
#    'id': '3761647',
#    'neo_reference_id': '3761647',
#    'name': '(2016 UY35)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3761647',
#    'absolute_magnitude_h': 24.7,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0305179233,
#      'estimated_diameter_max': 0.0682401509},
#     'meters': {'estimated_diameter_min': 30.5179232594,
#      'estimated_diameter_max': 68.2401509401},
#     'miles': {'estimated_diameter_min': 0.0189629525,
#      'estimated_diameter_max': 0.0424024508},
#     'feet': {'estimated_diameter_min': 100.1244233463,
#      'estimated_diameter_max': 223.8850168104}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 19:25',
#      'epoch_date_close_approach': 1729279500000,
#      'relative_velocity': {'kilometers_per_second': '18.0779724934',
#       'kilometers_per_hour': '65080.70097628',
#       'miles_per_hour': '40438.6166705113'},
#      'miss_distance': {'astronomical': '0.388914732',
#       'lunar': '151.287830748',
#       'kilometers': '58180815.51882084',
#       'miles': '36151882.378333992'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54016334?api_key=DEMO_KEY'},
#    'id': '54016334',
#    'neo_reference_id': '54016334',
#    'name': '(2020 FV3)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54016334',
#    'absolute_magnitude_h': 27.7,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0076657557,
#      'estimated_diameter_max': 0.0171411509},
#     'meters': {'estimated_diameter_min': 7.6657557353,
#      'estimated_diameter_max': 17.1411509231},
#     'miles': {'estimated_diameter_min': 0.0047632783,
#      'estimated_diameter_max': 0.0106510141},
#     'feet': {'estimated_diameter_min': 25.1501180466,
#      'estimated_diameter_max': 56.2373735944}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 02:36',
#      'epoch_date_close_approach': 1729218960000,
#      'relative_velocity': {'kilometers_per_second': '17.4745586299',
#       'kilometers_per_hour': '62908.4110676954',
#       'miles_per_hour': '39088.8401992578'},
#      'miss_distance': {'astronomical': '0.3951498466',
#       'lunar': '153.7132903274',
#       'kilometers': '59113575.382186742',
#       'miles': '36731472.4814793596'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54051583?api_key=DEMO_KEY'},
#    'id': '54051583',
#    'neo_reference_id': '54051583',
#    'name': '(2020 QP6)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54051583',
#    'absolute_magnitude_h': 20.73,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1899131235,
#      'estimated_diameter_max': 0.4246586539},
#     'meters': {'estimated_diameter_min': 189.9131234709,
#      'estimated_diameter_max': 424.6586539002},
#     'miles': {'estimated_diameter_min': 0.1180065074,
#      'estimated_diameter_max': 0.2638705724},
#     'feet': {'estimated_diameter_min': 623.0745720082,
#      'estimated_diameter_max': 1393.2370980619}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 12:02',
#      'epoch_date_close_approach': 1729252920000,
#      'relative_velocity': {'kilometers_per_second': '9.115305361',
#       'kilometers_per_hour': '32815.0992997171',
#       'miles_per_hour': '20390.0265620937'},
#      'miss_distance': {'astronomical': '0.2111664435',
#       'lunar': '82.1437465215',
#       'kilometers': '31590050.163075345',
#       'miles': '19629146.955695961'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54055117?api_key=DEMO_KEY'},
#    'id': '54055117',
#    'neo_reference_id': '54055117',
#    'name': '(2020 TN3)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54055117',
#    'absolute_magnitude_h': 24.2,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0384197891,
#      'estimated_diameter_max': 0.0859092601},
#     'meters': {'estimated_diameter_min': 38.4197891064,
#      'estimated_diameter_max': 85.9092601232},
#     'miles': {'estimated_diameter_min': 0.0238729428,
#      'estimated_diameter_max': 0.0533815229},
#     'feet': {'estimated_diameter_min': 126.0491808919,
#      'estimated_diameter_max': 281.8545369825}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 23:34',
#      'epoch_date_close_approach': 1729294440000,
#      'relative_velocity': {'kilometers_per_second': '18.9916021102',
#       'kilometers_per_hour': '68369.7675966044',
#       'miles_per_hour': '42482.3147602346'},
#      'miss_distance': {'astronomical': '0.1866409181',
#       'lunar': '72.6033171409',
#       'kilometers': '27921083.802604447',
#       'miles': '17349356.9745654886'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54316690?api_key=DEMO_KEY'},
#    'id': '54316690',
#    'neo_reference_id': '54316690',
#    'name': '(2022 UO)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54316690',
#    'absolute_magnitude_h': 26.53,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0131387781,
#      'estimated_diameter_max': 0.0293792009},
#     'meters': {'estimated_diameter_min': 13.1387780601,
#      'estimated_diameter_max': 29.3792008837},
#     'miles': {'estimated_diameter_min': 0.0081640557,
#      'estimated_diameter_max': 0.0182553834},
#     'feet': {'estimated_diameter_min': 43.1062286107,
#      'estimated_diameter_max': 96.3884574272}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 21:59',
#      'epoch_date_close_approach': 1729288740000,
#      'relative_velocity': {'kilometers_per_second': '16.29423043',
#       'kilometers_per_hour': '58659.2295480436',
#       'miles_per_hour': '36448.5640488941'},
#      'miss_distance': {'astronomical': '0.3065798839',
#       'lunar': '119.2595748371',
#       'kilometers': '45863697.616287293',
#       'miles': '28498380.2113109234'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54320707?api_key=DEMO_KEY'},
#    'id': '54320707',
#    'neo_reference_id': '54320707',
#    'name': '(2022 UO10)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54320707',
#    'absolute_magnitude_h': 26.76,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0118182991,
#      'estimated_diameter_max': 0.0264265201},
#     'meters': {'estimated_diameter_min': 11.8182990893,
#      'estimated_diameter_max': 26.4265201422},
#     'miles': {'estimated_diameter_min': 0.0073435483,
#      'estimated_diameter_max': 0.0164206732},
#     'feet': {'estimated_diameter_min': 38.7739483842,
#      'estimated_diameter_max': 86.7011843432}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 21:56',
#      'epoch_date_close_approach': 1729288560000,
#      'relative_velocity': {'kilometers_per_second': '10.3025532627',
#       'kilometers_per_hour': '37089.191745598',
#       'miles_per_hour': '23045.7813932578'},
#      'miss_distance': {'astronomical': '0.0522513469',
#       'lunar': '20.3257739441',
#       'kilometers': '7816690.200871103',
#       'miles': '4857066.0656751014'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54347994?api_key=DEMO_KEY'},
#    'id': '54347994',
#    'neo_reference_id': '54347994',
#    'name': '(2023 EN2)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54347994',
#    'absolute_magnitude_h': 23.12,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0631764148,
#      'estimated_diameter_max': 0.1412667581},
#     'meters': {'estimated_diameter_min': 63.1764148185,
#      'estimated_diameter_max': 141.2667581089},
#     'miles': {'estimated_diameter_min': 0.0392559921,
#      'estimated_diameter_max': 0.0877790668},
#     'feet': {'estimated_diameter_min': 207.2717087931,
#      'estimated_diameter_max': 463.4736306739}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 13:57',
#      'epoch_date_close_approach': 1729259820000,
#      'relative_velocity': {'kilometers_per_second': '23.4907483903',
#       'kilometers_per_hour': '84566.6942049158',
#       'miles_per_hour': '52546.4550741601'},
#      'miss_distance': {'astronomical': '0.4623701184',
#       'lunar': '179.8619760576',
#       'kilometers': '69169584.864287808',
#       'miles': '42979987.0261874304'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54445848?api_key=DEMO_KEY'},
#    'id': '54445848',
#    'neo_reference_id': '54445848',
#    'name': '(2024 LE1)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54445848',
#    'absolute_magnitude_h': 26.31,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0145396843,
#      'estimated_diameter_max': 0.0325117225},
#     'meters': {'estimated_diameter_min': 14.5396842937,
#      'estimated_diameter_max': 32.5117224521},
#     'miles': {'estimated_diameter_min': 0.0090345382,
#      'estimated_diameter_max': 0.0202018415},
#     'feet': {'estimated_diameter_min': 47.7023778182,
#      'estimated_diameter_max': 106.6657594899}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 10:04',
#      'epoch_date_close_approach': 1729245840000,
#      'relative_velocity': {'kilometers_per_second': '7.7794602138',
#       'kilometers_per_hour': '28006.0567697649',
#       'miles_per_hour': '17401.874552302'},
#      'miss_distance': {'astronomical': '0.3314508579',
#       'lunar': '128.9343837231',
#       'kilometers': '49584342.351512673',
#       'miles': '30810281.6454859674'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54482434?api_key=DEMO_KEY'},
#    'id': '54482434',
#    'neo_reference_id': '54482434',
#    'name': '(2024 RV50)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54482434',
#    'absolute_magnitude_h': 20.97,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1700415193,
#      'estimated_diameter_max': 0.3802243961},
#     'meters': {'estimated_diameter_min': 170.0415192713,
#      'estimated_diameter_max': 380.2243960879},
#     'miles': {'estimated_diameter_min': 0.1056588689,
#      'estimated_diameter_max': 0.2362604132},
#     'feet': {'estimated_diameter_min': 557.879018086,
#      'estimated_diameter_max': 1247.4554076612}},
#    'is_potentially_hazardous_asteroid': True,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 17:02',
#      'epoch_date_close_approach': 1729270920000,
#      'relative_velocity': {'kilometers_per_second': '15.5740330005',
#       'kilometers_per_hour': '56066.5188018022',
#       'miles_per_hour': '34837.5544188198'},
#      'miss_distance': {'astronomical': '0.0495817849',
#       'lunar': '19.2873143261',
#       'kilometers': '7417329.411838163',
#       'miles': '4608914.7782981294'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54487286?api_key=DEMO_KEY'},
#    'id': '54487286',
#    'neo_reference_id': '54487286',
#    'name': '(2024 TX2)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54487286',
#    'absolute_magnitude_h': 23.82,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0457672667,
#      'estimated_diameter_max': 0.1023387195},
#     'meters': {'estimated_diameter_min': 45.7672667231,
#      'estimated_diameter_max': 102.3387195373},
#     'miles': {'estimated_diameter_min': 0.0284384523,
#      'estimated_diameter_max': 0.0635903125},
#     'feet': {'estimated_diameter_min': 150.1550793559,
#      'estimated_diameter_max': 335.7569646067}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 03:16',
#      'epoch_date_close_approach': 1729221360000,
#      'relative_velocity': {'kilometers_per_second': '13.5391459573',
#       'kilometers_per_hour': '48740.9254462627',
#       'miles_per_hour': '30285.7155918736'},
#      'miss_distance': {'astronomical': '0.0763141963',
#       'lunar': '29.6862223607',
#       'kilometers': '11416441.217241881',
#       'miles': '7093847.6263087178'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54487954?api_key=DEMO_KEY'},
#    'id': '54487954',
#    'neo_reference_id': '54487954',
#    'name': '(2024 TN4)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54487954',
#    'absolute_magnitude_h': 22.57,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0813869881,
#      'estimated_diameter_max': 0.1819868378},
#     'meters': {'estimated_diameter_min': 81.3869880675,
#      'estimated_diameter_max': 181.9868378029},
#     'miles': {'estimated_diameter_min': 0.0505715142,
#      'estimated_diameter_max': 0.1130813434},
#     'feet': {'estimated_diameter_min': 267.0176859314,
#      'estimated_diameter_max': 597.0696969372}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 16:12',
#      'epoch_date_close_approach': 1729267920000,
#      'relative_velocity': {'kilometers_per_second': '11.860549732',
#       'kilometers_per_hour': '42697.979035376',
#       'miles_per_hour': '26530.8636956202'},
#      'miss_distance': {'astronomical': '0.2829878222',
#       'lunar': '110.0822628358',
#       'kilometers': '42334375.437058714',
#       'miles': '26305361.1007856932'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54489676?api_key=DEMO_KEY'},
#    'id': '54489676',
#    'neo_reference_id': '54489676',
#    'name': '(2024 TX8)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54489676',
#    'absolute_magnitude_h': 24.23,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0378926498,
#      'estimated_diameter_max': 0.0847305409},
#     'meters': {'estimated_diameter_min': 37.8926498379,
#      'estimated_diameter_max': 84.7305408852},
#     'miles': {'estimated_diameter_min': 0.0235453937,
#      'estimated_diameter_max': 0.0526491009},
#     'feet': {'estimated_diameter_min': 124.3197212943,
#      'estimated_diameter_max': 277.9873477579}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 18:01',
#      'epoch_date_close_approach': 1729274460000,
#      'relative_velocity': {'kilometers_per_second': '12.4967201863',
#       'kilometers_per_hour': '44988.1926707246',
#       'miles_per_hour': '27953.9133847622'},
#      'miss_distance': {'astronomical': '0.0942506329',
#       'lunar': '36.6634961981',
#       'kilometers': '14099693.927991923',
#       'miles': '8761143.5472296174'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54490132?api_key=DEMO_KEY'},
#    'id': '54490132',
#    'neo_reference_id': '54490132',
#    'name': '(2024 TT9)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54490132',
#    'absolute_magnitude_h': 24.2,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0384197891,
#      'estimated_diameter_max': 0.0859092601},
#     'meters': {'estimated_diameter_min': 38.4197891064,
#      'estimated_diameter_max': 85.9092601232},
#     'miles': {'estimated_diameter_min': 0.0238729428,
#      'estimated_diameter_max': 0.0533815229},
#     'feet': {'estimated_diameter_min': 126.0491808919,
#      'estimated_diameter_max': 281.8545369825}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 07:04',
#      'epoch_date_close_approach': 1729235040000,
#      'relative_velocity': {'kilometers_per_second': '14.7304381847',
#       'kilometers_per_hour': '53029.5774650305',
#       'miles_per_hour': '32950.5171754241'},
#      'miss_distance': {'astronomical': '0.0651937557',
#       'lunar': '25.3603709673',
#       'kilometers': '9752846.990020359',
#       'miles': '6060138.1072605942'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54494098?api_key=DEMO_KEY'},
#    'id': '54494098',
#    'neo_reference_id': '54494098',
#    'name': '(2024 TB22)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54494098',
#    'absolute_magnitude_h': 19.323,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.3630404163,
#      'estimated_diameter_max': 0.8117830495},
#     'meters': {'estimated_diameter_min': 363.0404163487,
#      'estimated_diameter_max': 811.7830495355},
#     'miles': {'estimated_diameter_min': 0.2255827865,
#      'estimated_diameter_max': 0.5044184453},
#     'feet': {'estimated_diameter_min': 1191.0775195734,
#      'estimated_diameter_max': 2663.3303002379}},
#    'is_potentially_hazardous_asteroid': True,
#    'close_approach_data': [{'close_approach_date': '2024-10-18',
#      'close_approach_date_full': '2024-Oct-18 01:51',
#      'epoch_date_close_approach': 1729216260000,
#      'relative_velocity': {'kilometers_per_second': '22.0048475276',
#       'kilometers_per_hour': '79217.4510991908',
#       'miles_per_hour': '49222.6434343833'},
#      'miss_distance': {'astronomical': '0.0764257156',
#       'lunar': '29.7296033684',
#       'kilometers': '11433124.266985772',
#       'miles': '7104213.9927247736'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False}],
#  '2024-10-17': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2462238?api_key=DEMO_KEY'},
#    'id': '2462238',
#    'neo_reference_id': '2462238',
#    'name': '462238 (2008 CN1)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2462238',
#    'absolute_magnitude_h': 20.66,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1961349444,
#      'estimated_diameter_max': 0.4385710684},
#     'meters': {'estimated_diameter_min': 196.1349443683,
#      'estimated_diameter_max': 438.5710683707},
#     'miles': {'estimated_diameter_min': 0.1218725665,
#      'estimated_diameter_max': 0.2725153433},
#     'feet': {'estimated_diameter_min': 643.4873708813,
#      'estimated_diameter_max': 1438.8815039533}},
#    'is_potentially_hazardous_asteroid': True,
#    'close_approach_data': [{'close_approach_date': '2024-10-17',
#      'close_approach_date_full': '2024-Oct-17 11:15',
#      'epoch_date_close_approach': 1729163700000,
#      'relative_velocity': {'kilometers_per_second': '15.3649328146',
#       'kilometers_per_hour': '55313.7581324034',
#       'miles_per_hour': '34369.8182128814'},
#      'miss_distance': {'astronomical': '0.4557169319',
#       'lunar': '177.2738865091',
#       'kilometers': '68174282.335175053',
#       'miles': '42361534.7126116114'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3388311?api_key=DEMO_KEY'},
#    'id': '3388311',
#    'neo_reference_id': '3388311',
#    'name': '(2007 TQ24)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3388311',
#    'absolute_magnitude_h': 22.06,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.102933082,
#      'estimated_diameter_max': 0.2301653685},
#     'meters': {'estimated_diameter_min': 102.9330820202,
#      'estimated_diameter_max': 230.1653685307},
#     'miles': {'estimated_diameter_min': 0.0639596321,
#      'estimated_diameter_max': 0.1430180852},
#     'feet': {'estimated_diameter_min': 337.706972815,
#      'estimated_diameter_max': 755.1357476901}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-17',
#      'close_approach_date_full': '2024-Oct-17 20:10',
#      'epoch_date_close_approach': 1729195800000,
#      'relative_velocity': {'kilometers_per_second': '12.2165910106',
#       'kilometers_per_hour': '43979.7276380045',
#       'miles_per_hour': '27327.2924315145'},
#      'miss_distance': {'astronomical': '0.2377570456',
#       'lunar': '92.4874907384',
#       'kilometers': '35567947.599252872',
#       'miles': '22100897.8059267536'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3775093?api_key=DEMO_KEY'},
#    'id': '3775093',
#    'neo_reference_id': '3775093',
#    'name': '(2017 KR31)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3775093',
#    'absolute_magnitude_h': 24.1,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.040230458,
#      'estimated_diameter_max': 0.0899580388},
#     'meters': {'estimated_diameter_min': 40.2304579834,
#      'estimated_diameter_max': 89.9580388169},
#     'miles': {'estimated_diameter_min': 0.0249980399,
#      'estimated_diameter_max': 0.0558973165},
#     'feet': {'estimated_diameter_min': 131.9896957704,
#      'estimated_diameter_max': 295.1379320721}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-17',
#      'close_approach_date_full': '2024-Oct-17 23:41',
#      'epoch_date_close_approach': 1729208460000,
#      'relative_velocity': {'kilometers_per_second': '14.067359043',
#       'kilometers_per_hour': '50642.4925548904',
#       'miles_per_hour': '31467.2754433428'},
#      'miss_distance': {'astronomical': '0.3808247036',
#       'lunar': '148.1408097004',
#       'kilometers': '56970564.501941332',
#       'miles': '35399867.2678491016'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3836113?api_key=DEMO_KEY'},
#    'id': '3836113',
#    'neo_reference_id': '3836113',
#    'name': '(2018 VW4)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3836113',
#    'absolute_magnitude_h': 24.52,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0331554538,
#      'estimated_diameter_max': 0.0741378485},
#     'meters': {'estimated_diameter_min': 33.1554538086,
#      'estimated_diameter_max': 74.1378485408},
#     'miles': {'estimated_diameter_min': 0.0206018375,
#      'estimated_diameter_max': 0.0460671091},
#     'feet': {'estimated_diameter_min': 108.7777390733,
#      'estimated_diameter_max': 243.2344190067}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-17',
#      'close_approach_date_full': '2024-Oct-17 20:20',
#      'epoch_date_close_approach': 1729196400000,
#      'relative_velocity': {'kilometers_per_second': '23.7531336241',
#       'kilometers_per_hour': '85511.2810467377',
#       'miles_per_hour': '53133.3846037354'},
#      'miss_distance': {'astronomical': '0.4353594536',
#       'lunar': '169.3548274504',
#       'kilometers': '65128846.942923832',
#       'miles': '40469188.9091076016'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3879238?api_key=DEMO_KEY'},
#    'id': '3879238',
#    'neo_reference_id': '3879238',
#    'name': '(2019 UZ)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3879238',
#    'absolute_magnitude_h': 27.8,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0073207399,
#      'estimated_diameter_max': 0.016369672},
#     'meters': {'estimated_diameter_min': 7.3207398935,
#      'estimated_diameter_max': 16.3696720474},
#     'miles': {'estimated_diameter_min': 0.0045488955,
#      'estimated_diameter_max': 0.0101716395},
#     'feet': {'estimated_diameter_min': 24.0181762721,
#      'estimated_diameter_max': 53.70627484}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-17',
#      'close_approach_date_full': '2024-Oct-17 08:38',
#      'epoch_date_close_approach': 1729154280000,
#      'relative_velocity': {'kilometers_per_second': '17.2745006981',
#       'kilometers_per_hour': '62188.2025131996',
#       'miles_per_hour': '38641.3306116045'},
#      'miss_distance': {'astronomical': '0.2446966636',
#       'lunar': '95.1870021404',
#       'kilometers': '36606099.670666532',
#       'miles': '22745975.5904488616'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3883101?api_key=DEMO_KEY'},
#    'id': '3883101',
#    'neo_reference_id': '3883101',
#    'name': '(2019 UZ7)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3883101',
#    'absolute_magnitude_h': 21.04,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1646474378,
#      'estimated_diameter_max': 0.3681628631},
#     'meters': {'estimated_diameter_min': 164.6474377554,
#      'estimated_diameter_max': 368.1628631423},
#     'miles': {'estimated_diameter_min': 0.102307143,
#      'estimated_diameter_max': 0.2287657264},
#     'feet': {'estimated_diameter_min': 540.1818996855,
#      'estimated_diameter_max': 1207.8834479116}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-17',
#      'close_approach_date_full': '2024-Oct-17 11:14',
#      'epoch_date_close_approach': 1729163640000,
#      'relative_velocity': {'kilometers_per_second': '21.8717027588',
#       'kilometers_per_hour': '78738.1299317441',
#       'miles_per_hour': '48924.8119011995'},
#      'miss_distance': {'astronomical': '0.4220248698',
#       'lunar': '164.1676743522',
#       'kilometers': '63134021.609107326',
#       'miles': '39229661.9243040588'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3892267?api_key=DEMO_KEY'},
#    'id': '3892267',
#    'neo_reference_id': '3892267',
#    'name': '(2019 UH14)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3892267',
#    'absolute_magnitude_h': 23.8,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.046190746,
#      'estimated_diameter_max': 0.1032856481},
#     'meters': {'estimated_diameter_min': 46.1907460282,
#      'estimated_diameter_max': 103.2856480504},
#     'miles': {'estimated_diameter_min': 0.0287015901,
#      'estimated_diameter_max': 0.0641787064},
#     'feet': {'estimated_diameter_min': 151.544447199,
#      'estimated_diameter_max': 338.8636855496}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-17',
#      'close_approach_date_full': '2024-Oct-17 15:49',
#      'epoch_date_close_approach': 1729180140000,
#      'relative_velocity': {'kilometers_per_second': '10.3320999537',
#       'kilometers_per_hour': '37195.5598332059',
#       'miles_per_hour': '23111.8743863606'},
#      'miss_distance': {'astronomical': '0.0203523129',
#       'lunar': '7.9170497181',
#       'kilometers': '3044662.659413523',
#       'miles': '1891865.6495836974'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3989721?api_key=DEMO_KEY'},
#    'id': '3989721',
#    'neo_reference_id': '3989721',
#    'name': '(2020 CU1)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3989721',
#    'absolute_magnitude_h': 24.19,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0385971268,
#      'estimated_diameter_max': 0.0863057993},
#     'meters': {'estimated_diameter_min': 38.5971267955,
#      'estimated_diameter_max': 86.3057992509},
#     'miles': {'estimated_diameter_min': 0.0239831353,
#      'estimated_diameter_max': 0.0536279208},
#     'feet': {'estimated_diameter_min': 126.6309974757,
#      'estimated_diameter_max': 283.1555184142}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-17',
#      'close_approach_date_full': '2024-Oct-17 05:05',
#      'epoch_date_close_approach': 1729141500000,
#      'relative_velocity': {'kilometers_per_second': '8.2046893125',
#       'kilometers_per_hour': '29536.8815250342',
#       'miles_per_hour': '18353.0695231525'},
#      'miss_distance': {'astronomical': '0.0952544442',
#       'lunar': '37.0539787938',
#       'kilometers': '14249861.960353854',
#       'miles': '8854453.6356930252'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54144232?api_key=DEMO_KEY'},
#    'id': '54144232',
#    'neo_reference_id': '54144232',
#    'name': '(2021 JN2)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54144232',
#    'absolute_magnitude_h': 23.77,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0468333233,
#      'estimated_diameter_max': 0.1047224945},
#     'meters': {'estimated_diameter_min': 46.8333233136,
#      'estimated_diameter_max': 104.7224945415},
#     'miles': {'estimated_diameter_min': 0.0291008689,
#      'estimated_diameter_max': 0.0650715212},
#     'feet': {'estimated_diameter_min': 153.6526404603,
#      'estimated_diameter_max': 343.5777489915}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-17',
#      'close_approach_date_full': '2024-Oct-17 12:56',
#      'epoch_date_close_approach': 1729169760000,
#      'relative_velocity': {'kilometers_per_second': '20.2193965004',
#       'kilometers_per_hour': '72789.8274015102',
#       'miles_per_hour': '45228.7680317884'},
#      'miss_distance': {'astronomical': '0.3693530654',
#       'lunar': '143.6783424406',
#       'kilometers': '55254431.861810698',
#       'miles': '34333511.8928277124'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54145782?api_key=DEMO_KEY'},
#    'id': '54145782',
#    'neo_reference_id': '54145782',
#    'name': '(2021 JG9)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54145782',
#    'absolute_magnitude_h': 25.2,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0242412481,
#      'estimated_diameter_max': 0.0542050786},
#     'meters': {'estimated_diameter_min': 24.2412481101,
#      'estimated_diameter_max': 54.2050786336},
#     'miles': {'estimated_diameter_min': 0.0150628086,
#      'estimated_diameter_max': 0.0336814639},
#     'feet': {'estimated_diameter_min': 79.5316564495,
#      'estimated_diameter_max': 177.8381901842}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-17',
#      'close_approach_date_full': '2024-Oct-17 07:47',
#      'epoch_date_close_approach': 1729151220000,
#      'relative_velocity': {'kilometers_per_second': '14.3161184392',
#       'kilometers_per_hour': '51538.0263811945',
#       'miles_per_hour': '32023.7253366928'},
#      'miss_distance': {'astronomical': '0.4395115161',
#       'lunar': '170.9699797629',
#       'kilometers': '65749986.649030707',
#       'miles': '40855147.2253574766'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54205435?api_key=DEMO_KEY'},
#    'id': '54205435',
#    'neo_reference_id': '54205435',
#    'name': '(2021 TN6)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54205435',
#    'absolute_magnitude_h': 25.06,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0258556212,
#      'estimated_diameter_max': 0.0578149266},
#     'meters': {'estimated_diameter_min': 25.855621208,
#      'estimated_diameter_max': 57.8149266216},
#     'miles': {'estimated_diameter_min': 0.0160659332,
#      'estimated_diameter_max': 0.0359245188},
#     'feet': {'estimated_diameter_min': 84.828156284,
#      'estimated_diameter_max': 189.6815238571}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-17',
#      'close_approach_date_full': '2024-Oct-17 03:45',
#      'epoch_date_close_approach': 1729136700000,
#      'relative_velocity': {'kilometers_per_second': '9.9869841071',
#       'kilometers_per_hour': '35953.14278569',
#       'miles_per_hour': '22339.8847492528'},
#      'miss_distance': {'astronomical': '0.4515758448',
#       'lunar': '175.6630036272',
#       'kilometers': '67554784.525530576',
#       'miles': '41976596.6235149088'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54243523?api_key=DEMO_KEY'},
#    'id': '54243523',
#    'neo_reference_id': '54243523',
#    'name': '(2022 BM5)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54243523',
#    'absolute_magnitude_h': 25.63,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0198863453,
#      'estimated_diameter_max': 0.04446722},
#     'meters': {'estimated_diameter_min': 19.8863453236,
#      'estimated_diameter_max': 44.4672199676},
#     'miles': {'estimated_diameter_min': 0.0123567983,
#      'estimated_diameter_max': 0.0276306409},
#     'feet': {'estimated_diameter_min': 65.2439171914,
#      'estimated_diameter_max': 145.8898339584}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-17',
#      'close_approach_date_full': '2024-Oct-17 19:53',
#      'epoch_date_close_approach': 1729194780000,
#      'relative_velocity': {'kilometers_per_second': '7.3368166987',
#       'kilometers_per_hour': '26412.540115155',
#       'miles_per_hour': '16411.7252732195'},
#      'miss_distance': {'astronomical': '0.3257502953',
#       'lunar': '126.7168648717',
#       'kilometers': '48731550.328751011',
#       'miles': '30280381.2543495118'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54393421?api_key=DEMO_KEY'},
#    'id': '54393421',
#    'neo_reference_id': '54393421',
#    'name': '(2023 TK12)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54393421',
#    'absolute_magnitude_h': 25.77,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0186446818,
#      'estimated_diameter_max': 0.041690776},
#     'meters': {'estimated_diameter_min': 18.644681832,
#      'estimated_diameter_max': 41.6907759952},
#     'miles': {'estimated_diameter_min': 0.0115852646,
#      'estimated_diameter_max': 0.0259054392},
#     'feet': {'estimated_diameter_min': 61.1702179417,
#      'estimated_diameter_max': 136.7807655161}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-17',
#      'close_approach_date_full': '2024-Oct-17 02:30',
#      'epoch_date_close_approach': 1729132200000,
#      'relative_velocity': {'kilometers_per_second': '18.9889273099',
#       'kilometers_per_hour': '68360.1383155705',
#       'miles_per_hour': '42476.3314994721'},
#      'miss_distance': {'astronomical': '0.2124967045',
#       'lunar': '82.6612180505',
#       'kilometers': '31789054.375219415',
#       'miles': '19752802.439141327'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54395029?api_key=DEMO_KEY'},
#    'id': '54395029',
#    'neo_reference_id': '54395029',
#    'name': '(2023 UH)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54395029',
#    'absolute_magnitude_h': 26.13,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0157962856,
#      'estimated_diameter_max': 0.0353215683},
#     'meters': {'estimated_diameter_min': 15.796285576,
#      'estimated_diameter_max': 35.3215683399},
#     'miles': {'estimated_diameter_min': 0.0098153538,
#      'estimated_diameter_max': 0.0219477982},
#     'feet': {'estimated_diameter_min': 51.8250855692,
#      'estimated_diameter_max': 115.8844142724}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-17',
#      'close_approach_date_full': '2024-Oct-17 15:41',
#      'epoch_date_close_approach': 1729179660000,
#      'relative_velocity': {'kilometers_per_second': '11.8015350248',
#       'kilometers_per_hour': '42485.5260894298',
#       'miles_per_hour': '26398.8536970682'},
#      'miss_distance': {'astronomical': '0.3543875127',
#       'lunar': '137.8567424403',
#       'kilometers': '53015617.054517949',
#       'miles': '32942376.8793637362'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54467171?api_key=DEMO_KEY'},
#    'id': '54467171',
#    'neo_reference_id': '54467171',
#    'name': '(2024 NN11)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54467171',
#    'absolute_magnitude_h': 19.31,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.365220357,
#      'estimated_diameter_max': 0.8166575449},
#     'meters': {'estimated_diameter_min': 365.2203569583,
#      'estimated_diameter_max': 816.6575449256},
#     'miles': {'estimated_diameter_min': 0.2269373384,
#      'estimated_diameter_max': 0.5074473153},
#     'feet': {'estimated_diameter_min': 1198.2295559232,
#      'estimated_diameter_max': 2679.3227396936}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-17',
#      'close_approach_date_full': '2024-Oct-17 12:36',
#      'epoch_date_close_approach': 1729168560000,
#      'relative_velocity': {'kilometers_per_second': '7.8808285914',
#       'kilometers_per_hour': '28370.9829291579',
#       'miles_per_hour': '17628.6254761759'},
#      'miss_distance': {'astronomical': '0.4123663341',
#       'lunar': '160.4105039649',
#       'kilometers': '61689125.241068367',
#       'miles': '38331844.9535307846'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54482419?api_key=DEMO_KEY'},
#    'id': '54482419',
#    'neo_reference_id': '54482419',
#    'name': '(2024 SD2)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54482419',
#    'absolute_magnitude_h': 25.65,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0197040262,
#      'estimated_diameter_max': 0.044059542},
#     'meters': {'estimated_diameter_min': 19.7040262138,
#      'estimated_diameter_max': 44.0595420444},
#     'miles': {'estimated_diameter_min': 0.0122435105,
#      'estimated_diameter_max': 0.0273773217},
#     'feet': {'estimated_diameter_min': 64.6457573632,
#      'estimated_diameter_max': 144.5523079211}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-17',
#      'close_approach_date_full': '2024-Oct-17 00:34',
#      'epoch_date_close_approach': 1729125240000,
#      'relative_velocity': {'kilometers_per_second': '6.0977852005',
#       'kilometers_per_hour': '21952.0267216332',
#       'miles_per_hour': '13640.1357148948'},
#      'miss_distance': {'astronomical': '0.0258640747',
#       'lunar': '10.0611250583',
#       'kilometers': '3869210.484640889',
#       'miles': '2404215.9101827082'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54483132?api_key=DEMO_KEY'},
#    'id': '54483132',
#    'neo_reference_id': '54483132',
#    'name': '(2024 ST2)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54483132',
#    'absolute_magnitude_h': 25.14,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0249203981,
#      'estimated_diameter_max': 0.0557237043},
#     'meters': {'estimated_diameter_min': 24.9203981441,
#      'estimated_diameter_max': 55.7237042765},
#     'miles': {'estimated_diameter_min': 0.0154848127,
#      'estimated_diameter_max': 0.0346250939},
#     'feet': {'estimated_diameter_min': 81.7598390471,
#      'estimated_diameter_max': 182.8205579387}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-17',
#      'close_approach_date_full': '2024-Oct-17 17:24',
#      'epoch_date_close_approach': 1729185840000,
#      'relative_velocity': {'kilometers_per_second': '4.7190369218',
#       'kilometers_per_hour': '16988.5329183524',
#       'miles_per_hour': '10556.0136902951'},
#      'miss_distance': {'astronomical': '0.0900037714',
#       'lunar': '35.0114670746',
#       'kilometers': '13464372.493406918',
#       'miles': '8366373.1135267484'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54483152?api_key=DEMO_KEY'},
#    'id': '54483152',
#    'neo_reference_id': '54483152',
#    'name': '(2024 SP3)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54483152',
#    'absolute_magnitude_h': 21.84,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1139081967,
#      'estimated_diameter_max': 0.2547064711},
#     'meters': {'estimated_diameter_min': 113.9081967216,
#      'estimated_diameter_max': 254.706471064},
#     'miles': {'estimated_diameter_min': 0.0707792501,
#      'estimated_diameter_max': 0.1582672146},
#     'feet': {'estimated_diameter_min': 373.7145681322,
#      'estimated_diameter_max': 835.6511785256}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-17',
#      'close_approach_date_full': '2024-Oct-17 00:30',
#      'epoch_date_close_approach': 1729125000000,
#      'relative_velocity': {'kilometers_per_second': '4.0814310006',
#       'kilometers_per_hour': '14693.1516020895',
#       'miles_per_hour': '9129.7530051983'},
#      'miss_distance': {'astronomical': '0.3151563191',
#       'lunar': '122.5958081299',
#       'kilometers': '47146714.054400317',
#       'miles': '29295609.6579336946'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54487060?api_key=DEMO_KEY'},
#    'id': '54487060',
#    'neo_reference_id': '54487060',
#    'name': '(2024 TO1)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54487060',
#    'absolute_magnitude_h': 25.62,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0199781365,
#      'estimated_diameter_max': 0.0446724713},
#     'meters': {'estimated_diameter_min': 19.978136523,
#      'estimated_diameter_max': 44.6724713292},
#     'miles': {'estimated_diameter_min': 0.0124138347,
#      'estimated_diameter_max': 0.0277581782},
#     'feet': {'estimated_diameter_min': 65.5450694301,
#      'estimated_diameter_max': 146.5632308357}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-17',
#      'close_approach_date_full': '2024-Oct-17 21:39',
#      'epoch_date_close_approach': 1729201140000,
#      'relative_velocity': {'kilometers_per_second': '6.5609162288',
#       'kilometers_per_hour': '23619.2984236525',
#       'miles_per_hour': '14676.1135121857'},
#      'miss_distance': {'astronomical': '0.0565436633',
#       'lunar': '21.9954850237',
#       'kilometers': '8458811.591677171',
#       'miles': '5256061.7962441198'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54490139?api_key=DEMO_KEY'},
#    'id': '54490139',
#    'neo_reference_id': '54490139',
#    'name': '(2024 TC10)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54490139',
#    'absolute_magnitude_h': 21.55,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1301832102,
#      'estimated_diameter_max': 0.2910985075},
#     'meters': {'estimated_diameter_min': 130.1832101881,
#      'estimated_diameter_max': 291.0985075098},
#     'miles': {'estimated_diameter_min': 0.0808920715,
#      'estimated_diameter_max': 0.1808801707},
#     'feet': {'estimated_diameter_min': 427.1102833136,
#      'estimated_diameter_max': 955.0476273785}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-17',
#      'close_approach_date_full': '2024-Oct-17 20:45',
#      'epoch_date_close_approach': 1729197900000,
#      'relative_velocity': {'kilometers_per_second': '18.9817398741',
#       'kilometers_per_hour': '68334.2635467978',
#       'miles_per_hour': '42460.2539243978'},
#      'miss_distance': {'astronomical': '0.3450853719',
#       'lunar': '134.2382096691',
#       'kilometers': '51624036.604397853',
#       'miles': '32077688.8837742514'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54490522?api_key=DEMO_KEY'},
#    'id': '54490522',
#    'neo_reference_id': '54490522',
#    'name': '(2024 TQ11)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54490522',
#    'absolute_magnitude_h': 23.141,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0625683895,
#      'estimated_diameter_max': 0.1399071722},
#     'meters': {'estimated_diameter_min': 62.5683895221,
#      'estimated_diameter_max': 139.9071722141},
#     'miles': {'estimated_diameter_min': 0.0388781828,
#      'estimated_diameter_max': 0.0869342595},
#     'feet': {'estimated_diameter_min': 205.2768750797,
#      'estimated_diameter_max': 459.013046887}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-17',
#      'close_approach_date_full': '2024-Oct-17 13:19',
#      'epoch_date_close_approach': 1729171140000,
#      'relative_velocity': {'kilometers_per_second': '13.6013985235',
#       'kilometers_per_hour': '48965.0346845633',
#       'miles_per_hour': '30424.9683571943'},
#      'miss_distance': {'astronomical': '0.1844005452',
#       'lunar': '71.7318120828',
#       'kilometers': '27585928.788758724',
#       'miles': '17141101.3059054312'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54491553?api_key=DEMO_KEY'},
#    'id': '54491553',
#    'neo_reference_id': '54491553',
#    'name': '(2024 TC15)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54491553',
#    'absolute_magnitude_h': 26.862,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0112759976,
#      'estimated_diameter_max': 0.0252138973},
#     'meters': {'estimated_diameter_min': 11.2759976479,
#      'estimated_diameter_max': 25.2138972547},
#     'miles': {'estimated_diameter_min': 0.0070065779,
#      'estimated_diameter_max': 0.0156671846},
#     'feet': {'estimated_diameter_min': 36.994744123,
#      'estimated_diameter_max': 82.7227626692}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-10-17',
#      'close_approach_date_full': '2024-Oct-17 20:49',
#      'epoch_date_close_approach': 1729198140000,
#      'relative_velocity': {'kilometers_per_second': '9.2205371483',
#       'kilometers_per_hour': '33193.9337339643',
#       'miles_per_hour': '20625.4195470847'},
#      'miss_distance': {'astronomical': '0.0122662327',
#       'lunar': '4.7715645203',
#       'kilometers': '1835002.284844349',
#       'miles': '1140217.5472120562'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False}]}

# %% [markdown]
# Creo la estructura para el dataframe con los datos de las columnas en español para que sean comprensibles y con los elementos que me interesan

# %%
# Extraigo el diccionario del objeto data que contiene la información de las fechas indicadas en la petición a la API, el diccionario de tal manera que las claves son las fechas y los valores son listas de asteriodes que se acercarán en esas fechas

near_earth_objects = data['near_earth_objects']

# inicializo una lista vacía donde se almacenarán los datos en formato diccionario, para posteriormente crear el dataframe

all_neo_data = []

# Se realiza un bucle sobre las fechas, se itera sobre cada clave o fecha y se hace un bucle sobre los asteriodes
for date in near_earth_objects:
    for neo in near_earth_objects[date]:
        neo_data = {
            'id': neo['id'],
            'nombre': neo['name'],
            'magnitud_absoluta_h': neo['absolute_magnitude_h'],
            'diametro_min_estimado_km': neo['estimated_diameter']['kilometers']['estimated_diameter_min'],
            'diametro_max_estimado_km': neo['estimated_diameter']['kilometers']['estimated_diameter_max'],
            'potencialmente_peligroso': neo['is_potentially_hazardous_asteroid'],
            'fecha_aproximacion_cercana': neo['close_approach_data'][0]['close_approach_date'],
            'velocidad_relativa_km_per_seg': neo['close_approach_data'][0]['relative_velocity']['kilometers_per_second'],
            'distancia_fallo_km': neo['close_approach_data'][0]['miss_distance']['kilometers'],
            'cuerpo_que_orbita': neo['close_approach_data'][0]['orbiting_body']
        }
        all_neo_data.append(neo_data) # Se crea el diccionario (neo_data) donde se almacena la información de cada asteroide en el diccionario vacío (all_neo_data)

# Convierto los datos en un Dataframe e imprimo el resultado

df_neo = pd.DataFrame(all_neo_data)

# Muestro el resultado

df_neo
# Out:
#           id              nombre  magnitud_absoluta_h  \
# 0    2483547  483547 (2003 WM25)               17.650
# 1    3137843         (2002 RD27)               18.140
# 2    3145497          (2002 YO2)               22.700
# 3    3529626           (2010 MA)               25.700
# 4    3761647         (2016 UY35)               24.700
# 5   54016334          (2020 FV3)               27.700
# 6   54051583          (2020 QP6)               20.730
# 7   54055117          (2020 TN3)               24.200
# 8   54316690           (2022 UO)               26.530
# 9   54320707         (2022 UO10)               26.760
# 10  54347994          (2023 EN2)               23.120
# 11  54445848          (2024 LE1)               26.310
# 12  54482434         (2024 RV50)               20.970
# 13  54487286          (2024 TX2)               23.820
# 14  54487954          (2024 TN4)               22.570
# 15  54489676          (2024 TX8)               24.230
# 16  54490132          (2024 TT9)               24.200
# 17  54494098         (2024 TB22)               19.323
# 18   2462238   462238 (2008 CN1)               20.660
# 19   3388311         (2007 TQ24)               22.060
# 20   3775093         (2017 KR31)               24.100
# 21   3836113          (2018 VW4)               24.520
# 22   3879238           (2019 UZ)               27.800
# 23   3883101          (2019 UZ7)               21.040
# 24   3892267         (2019 UH14)               23.800
# 25   3989721          (2020 CU1)               24.190
# 26  54144232          (2021 JN2)               23.770
# 27  54145782          (2021 JG9)               25.200
# 28  54205435          (2021 TN6)               25.060
# 29  54243523          (2022 BM5)               25.630
# 30  54393421         (2023 TK12)               25.770
# 31  54395029           (2023 UH)               26.130
# 32  54467171         (2024 NN11)               19.310
# 33  54482419          (2024 SD2)               25.650
# 34  54483132          (2024 ST2)               25.140
# 35  54483152          (2024 SP3)               21.840
# 36  54487060          (2024 TO1)               25.620
# 37  54490139         (2024 TC10)               21.550
# 38  54490522         (2024 TQ11)               23.141
# 39  54491553         (2024 TC15)               26.862
#
#     diametro_min_estimado_km  diametro_max_estimado_km  \
# 0                   0.784431                  1.754042
# 1                   0.625972                  1.399716
# 2                   0.076658                  0.171412
# 3                   0.019256                  0.043057
# 4                   0.030518                  0.068240
# 5                   0.007666                  0.017141
# 6                   0.189913                  0.424659
# 7                   0.038420                  0.085909
# 8                   0.013139                  0.029379
# 9                   0.011818                  0.026427
# 10                  0.063176                  0.141267
# 11                  0.014540                  0.032512
# 12                  0.170042                  0.380224
# 13                  0.045767                  0.102339
# 14                  0.081387                  0.181987
# 15                  0.037893                  0.084731
# 16                  0.038420                  0.085909
# 17                  0.363040                  0.811783
# 18                  0.196135                  0.438571
# 19                  0.102933                  0.230165
# 20                  0.040230                  0.089958
# 21                  0.033155                  0.074138
# 22                  0.007321                  0.016370
# 23                  0.164647                  0.368163
# 24                  0.046191                  0.103286
# 25                  0.038597                  0.086306
# 26                  0.046833                  0.104722
# 27                  0.024241                  0.054205
# 28                  0.025856                  0.057815
# 29                  0.019886                  0.044467
# 30                  0.018645                  0.041691
# 31                  0.015796                  0.035322
# 32                  0.365220                  0.816658
# 33                  0.019704                  0.044060
# 34                  0.024920                  0.055724
# 35                  0.113908                  0.254706
# 36                  0.019978                  0.044672
# 37                  0.130183                  0.291099
# 38                  0.062568                  0.139907
# 39                  0.011276                  0.025214
#
#     potencialmente_peligroso fecha_aproximacion_cercana  \
# 0                      False                 2024-10-18
# 1                      False                 2024-10-18
# 2                      False                 2024-10-18
# 3                      False                 2024-10-18
# 4                      False                 2024-10-18
# 5                      False                 2024-10-18
# 6                      False                 2024-10-18
# 7                      False                 2024-10-18
# 8                      False                 2024-10-18
# 9                      False                 2024-10-18
# 10                     False                 2024-10-18
# 11                     False                 2024-10-18
# 12                      True                 2024-10-18
# 13                     False                 2024-10-18
# 14                     False                 2024-10-18
# 15                     False                 2024-10-18
# 16                     False                 2024-10-18
# 17                      True                 2024-10-18
# 18                      True                 2024-10-17
# 19                     False                 2024-10-17
# 20                     False                 2024-10-17
# 21                     False                 2024-10-17
# 22                     False                 2024-10-17
# 23                     False                 2024-10-17
# 24                     False                 2024-10-17
# 25                     False                 2024-10-17
# 26                     False                 2024-10-17
# 27                     False                 2024-10-17
# 28                     False                 2024-10-17
# 29                     False                 2024-10-17
# 30                     False                 2024-10-17
# 31                     False                 2024-10-17
# 32                     False                 2024-10-17
# 33                     False                 2024-10-17
# 34                     False                 2024-10-17
# 35                     False                 2024-10-17
# 36                     False                 2024-10-17
# 37                     False                 2024-10-17
# 38                     False                 2024-10-17
# 39                     False                 2024-10-17
#
#    velocidad_relativa_km_per_seg  distancia_fallo_km cuerpo_que_orbita
# 0                   9.3986954613  36254254.770454259             Earth
# 1                  12.6975359942  69734228.456075999             Earth
# 2                   4.4510357534  69033272.631524638             Earth
# 3                   8.5877838298  46135839.613723096             Earth
# 4                  18.0779724934   58180815.51882084             Earth
# 5                  17.4745586299  59113575.382186742             Earth
# 6                    9.115305361  31590050.163075345             Earth
# 7                  18.9916021102  27921083.802604447             Earth
# 8                    16.29423043  45863697.616287293             Earth
# 9                  10.3025532627   7816690.200871103             Earth
# 10                 23.4907483903  69169584.864287808             Earth
# 11                  7.7794602138  49584342.351512673             Earth
# 12                 15.5740330005   7417329.411838163             Earth
# 13                 13.5391459573  11416441.217241881             Earth
# 14                  11.860549732  42334375.437058714             Earth
# 15                 12.4967201863  14099693.927991923             Earth
# 16                 14.7304381847   9752846.990020359             Earth
# 17                 22.0048475276  11433124.266985772             Earth
# 18                 15.3649328146  68174282.335175053             Earth
# 19                 12.2165910106  35567947.599252872             Earth
# 20                  14.067359043  56970564.501941332             Earth
# 21                 23.7531336241  65128846.942923832             Earth
# 22                 17.2745006981  36606099.670666532             Earth
# 23                 21.8717027588  63134021.609107326             Earth
# 24                 10.3320999537   3044662.659413523             Earth
# 25                  8.2046893125  14249861.960353854             Earth
# 26                 20.2193965004  55254431.861810698             Earth
# 27                 14.3161184392  65749986.649030707             Earth
# 28                  9.9869841071  67554784.525530576             Earth
# 29                  7.3368166987  48731550.328751011             Earth
# 30                 18.9889273099  31789054.375219415             Earth
# 31                 11.8015350248  53015617.054517949             Earth
# 32                  7.8808285914  61689125.241068367             Earth
# 33                  6.0977852005   3869210.484640889             Earth
# 34                  4.7190369218  13464372.493406918             Earth
# 35                  4.0814310006  47146714.054400317             Earth
# 36                  6.5609162288   8458811.591677171             Earth
# 37                 18.9817398741  51624036.604397853             Earth
# 38                 13.6013985235  27585928.788758724             Earth
# 39                  9.2205371483   1835002.284844349             Earth

# %% [markdown]
# Quiero saber de toda esta lista cuales son los potencialmente peligrosos

# %%
cantidad_peligrosos = df_neo['potencialmente_peligroso'].sum()

print(f'Cantidad de objetos potencialmente peligrosos: {cantidad_peligrosos}')
# Out:
# Cantidad de objetos potencialmente peligrosos: 3

# %% [markdown]
# Quiero saber cuáles son estos objetos

# %%
objetos_peligrosos = df_neo['potencialmente_peligroso'] == True

df_neo[objetos_peligrosos]
# Out:
#           id             nombre  magnitud_absoluta_h  \
# 12  54482434        (2024 RV50)               20.970
# 17  54494098        (2024 TB22)               19.323
# 18   2462238  462238 (2008 CN1)               20.660
#
#     diametro_min_estimado_km  diametro_max_estimado_km  \
# 12                  0.170042                  0.380224
# 17                  0.363040                  0.811783
# 18                  0.196135                  0.438571
#
#     potencialmente_peligroso fecha_aproximacion_cercana  \
# 12                      True                 2024-10-18
# 17                      True                 2024-10-18
# 18                      True                 2024-10-17
#
#    velocidad_relativa_km_per_seg  distancia_fallo_km cuerpo_que_orbita
# 12                 15.5740330005   7417329.411838163             Earth
# 17                 22.0048475276  11433124.266985772             Earth
# 18                 15.3649328146  68174282.335175053             Earth

# %% [markdown]
# Con la información de esta consulta destaco por ejemplo el objeto ***2024 TB22*** (índice 17) se considera potencialmente peligroso, explico los valores obtenidos de este objeto:
#
# - **Magnitud absoluta:** 19.32 (la brillo del objeto, cuando menor el número más brillantes y por lo tanto más grande, ejemplo: el planeta Venus tiene una magnitud de -4,38, una estrella como Polaris, la estrella polar es de +1.97 )
#
# - **Diámetro estimado:** entre 363 y 812 mts. De impactar en la tierra podría causar un daño regional significativo.
#
# - **Potencialmente peligroso:** True, la NASA lo considera potencialmente peligroso.
#
# - **Fecha de aproximación cercana:** 18 de octubre de 2024
#
# - **Velocidad relativa:** 22 km/s velocidad extremadamente alta en relación con la tierra, en caso de impacto la energía sería considerable.
#
# - **Distancia de fallo:** 11 millones de km. aunque esté clasificado como potencialmente peligroso, pasará a una distancia segura (más lejos que la distancia entre la tierra y la luna)
#
# - **Trayectoria:** tiene una trayectoria que lo llevará cerca de la tierra.
